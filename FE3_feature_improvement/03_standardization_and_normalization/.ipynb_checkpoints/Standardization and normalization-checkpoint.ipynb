# %%
# import packages we need for exploratory data analysis (EDA)
import pandas as pd # to store tabular data
import numpy as np # to do some math
import matplotlib.pyplot as plt # a popular data visualization tool
import seaborn as sns # another popular data visualization tool
from sklearn.preprocessing import Imputer
# %matplotlib inline
plt.style.use('fivethirtyeight') # a popular data visualization theme

# %%
# load in our dataset using pandas
pima = pd.read_csv('./data/diabetes.csv')
pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# we will want to fill in missing values to see all 9 columns
impute = Imputer(strategy='mean')
pima_imputed_mean = pd.DataFrame(impute.fit_transform(pima), columns = pima.columns)

# %%
pima_imputed_mean.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2954e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f3f5cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f79b5f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7cb0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7eeb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7eeb70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f84b0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f870b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f89e5f8>]],
#       dtype=object)

# %%
pima_imputed_mean.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# with the same x axis (the y axis is not as important here)
pima_imputed_mean.hist(figsize=(15, 15), sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1fa9c320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fe9e3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1febc978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1fee7f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ff18518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ff18550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ff720b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f92ca58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ffb9a90>]],
#       dtype=object)

# %%
print(pima['Glucose'].head())
# Out:
# 0    148
# 1     85
# 2    183
# 3     89
# 4    137
# Name: Glucose, dtype: int64

# %%
# get the mean of the column
mu = pima['Glucose'].mean()

# get the standard deviation of the column
sigma = pima['Glucose'].std()

# calculate z scores for every value in the coulmn
print(((pima['Glucose'] - mu) / sigma).head())
# Out:
# 0    0.847771
# 1   -1.122665
# 2    1.942458
# 3   -0.997558
# 4    0.503727
# Name: Glucose, dtype: float64
